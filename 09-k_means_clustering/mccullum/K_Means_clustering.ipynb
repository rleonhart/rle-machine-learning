# %% [markdown]
# Based on https://nickmccullum.com/python-machine-learning/k-means-clustering-python/

# %% [markdown]
# # The Data Set We Will Use

# %%
from sklearn.datasets import make_blobs

raw_data = make_blobs(n_samples = 200, n_features = 2, centers = 4, cluster_std = 1.8)

# %% [markdown]
# # Visualizing Our Data Set

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

plt.scatter(raw_data[0][:,0], raw_data[0][:,1], c=raw_data[1])

# %% [markdown]
# # Building and Training Our K Means Clustering Model

# %%
from sklearn.cluster import KMeans

model = KMeans(n_clusters=4)

model.fit(raw_data[0])
# Out:
# KMeans(n_clusters=4)

# %% [markdown]
# # Making Predictions With Our K Means Clustering Model

# %%
model.labels_
# Out:
# array([2, 1, 3, 3, 1, 1, 3, 3, 2, 0, 3, 1, 1, 0, 0, 1, 2, 1, 3, 1, 1, 0,
#        2, 1, 2, 0, 0, 1, 3, 3, 2, 1, 3, 2, 3, 2, 2, 2, 0, 1, 3, 3, 0, 3,
#        0, 0, 2, 1, 1, 0, 1, 2, 0, 3, 2, 2, 3, 3, 2, 1, 2, 3, 1, 3, 2, 0,
#        0, 1, 0, 3, 2, 2, 1, 3, 2, 0, 2, 1, 0, 3, 2, 2, 2, 0, 2, 2, 2, 0,
#        2, 2, 2, 1, 2, 3, 1, 1, 1, 0, 3, 1, 0, 2, 3, 3, 2, 2, 2, 0, 0, 0,
#        2, 1, 0, 0, 1, 1, 1, 0, 1, 1, 1, 2, 1, 1, 2, 1, 1, 2, 2, 0, 2, 0,
#        3, 2, 2, 1, 3, 1, 0, 1, 2, 1, 3, 1, 0, 1, 3, 3, 0, 2, 3, 0, 3, 2,
#        1, 2, 0, 1, 0, 3, 3, 2, 0, 3, 1, 1, 2, 3, 3, 3, 3, 3, 0, 0, 0, 0,
#        2, 0, 2, 2, 1, 0, 2, 0, 0, 3, 0, 0, 0, 2, 1, 1, 0, 3, 2, 3, 0, 3,
#        0, 2], dtype=int32)

# %%
model.cluster_centers_
# Out:
# array([[-0.71646866,  0.63658331],
#        [ 6.8539205 , -7.795117  ],
#        [-9.22210872, -7.94086066],
#        [-7.24455275, -5.59630512]])

# %% [markdown]
# # Visualizing the Accuracy of Our Model

# %%
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(10,6))

ax1.set_title('Our Model')

ax1.scatter(raw_data[0][:,0], raw_data[0][:,1],c=model.labels_)

ax2.set_title('Original Data')

ax2.scatter(raw_data[0][:,0], raw_data[0][:,1],c=raw_data[1])
